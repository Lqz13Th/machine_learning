# %%
import polars as pl

sig_df = pl.read_parquet("C:/quant/data/utils/label_df.parquet.gzip")
label_df = pl.read_parquet("C:/quant/data/utils/integrated_forecast.parquet.gzip")

# %%
sig_df
# Out:
# shape: (1_755_907, 51)
# ┌──────────────┬──────────┬──────────┬──────────┬───┬───────────┬───────────┬───────────┬─────────────────────────┐
# │ 1000SHIBUSDT ┆ AAVEUSDT ┆ ADAUSDT  ┆ ALGOUSDT ┆ … ┆ XMRUSDT   ┆ XRPUSDT   ┆ ZECUSDT   ┆ Close_time              │
# │ ---          ┆ ---      ┆ ---      ┆ ---      ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---                     │
# │ f64          ┆ f64      ┆ f64      ┆ f64      ┆   ┆ f64       ┆ f64       ┆ f64       ┆ datetime[ns, UTC]       │
# ╞══════════════╪══════════╪══════════╪══════════╪═══╪═══════════╪═══════════╪═══════════╪═════════════════════════╡
# │ -0.001589    ┆ 0.002818 ┆ 0.001461 ┆ 0.001154 ┆ … ┆ -0.000647 ┆ -0.001277 ┆ -0.000927 ┆ 2022-02-28 23:51:00 UTC │
# │ -0.001589    ┆ 0.002818 ┆ 0.001461 ┆ 0.001154 ┆ … ┆ -0.000647 ┆ -0.001277 ┆ -0.000927 ┆ 2022-02-28 23:52:00 UTC │
# │ -0.001589    ┆ 0.002818 ┆ 0.001461 ┆ 0.001154 ┆ … ┆ -0.000647 ┆ -0.001277 ┆ -0.000927 ┆ 2022-02-28 23:53:00 UTC │
# ...

# %%
label_df
# Out:
# shape: (1_403_121, 51)
# ┌──────────────┬───────────┬───────────┬──────────┬───┬──────────┬──────────┬───────────┬─────────────────────────┐
# │ 1000SHIBUSDT ┆ AAVEUSDT  ┆ ADAUSDT   ┆ ALGOUSDT ┆ … ┆ XMRUSDT  ┆ XRPUSDT  ┆ ZECUSDT   ┆ Close_time              │
# │ ---          ┆ ---       ┆ ---       ┆ ---      ┆   ┆ ---      ┆ ---      ┆ ---       ┆ ---                     │
# │ f64          ┆ f64       ┆ f64       ┆ f64      ┆   ┆ f64      ┆ f64      ┆ f64       ┆ datetime[ns, UTC]       │
# ╞══════════════╪═══════════╪═══════════╪══════════╪═══╪══════════╪══════════╪═══════════╪═════════════════════════╡
# │ 0.0028       ┆ 0.004397  ┆ 0.002408  ┆ 0.004826 ┆ … ┆ -0.0015  ┆ 0.003748 ┆ 0.002571  ┆ 2022-11-01 00:30:00 UTC │
# │ 0.0028       ┆ 0.004397  ┆ 0.002408  ┆ 0.004826 ┆ … ┆ -0.0015  ┆ 0.003748 ┆ 0.002571  ┆ 2022-11-01 00:31:00 UTC │
# │ 0.0028       ┆ 0.004397  ┆ 0.002408  ┆ 0.004826 ┆ … ┆ -0.0015  ┆ 0.003748 ┆ 0.002571  ┆ 2022-11-01 00:32:00 UTC │
# ...
